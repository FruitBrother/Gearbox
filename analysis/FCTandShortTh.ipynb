# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from collections import OrderedDict
import matplotlib.pyplot as plt
import math
import JupyterImport
from IPython.display import display, HTML

# %%
from FCT import FCT
from shortTh import *
from delay import *
# Out:
# importing Jupyter notebook from FCT.ipynb
# importing Jupyter notebook from shortTh.ipynb
# importing Jupyter notebook from delay.ipynb

# %%
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
# print([FCT_analysis.humanbytes(i*1500) for i in flow_size])
algs=["DropTail"]


FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-small.tcl",\
                   10, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)


FCT_analysis_normal = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode.tcl",\
                   10, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_normal.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)        


FCT_analysis_big = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-big.tcl",\
                   10, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_big.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)
# Out:
# tcp_DropTail_flow_10_0.5_Topology-incast-singlenode-small.tcl.tr
# 0
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 6       6.0       0.000051       10          0         0    1    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 6   1  0.0  0.0   0  1.362809e+09    1.007847       29.351142
# 13
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 4      16.0       0.000077       14          0         0    0    0    3   1
# 7      19.0       0.000078       22          0         0    1    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 4   1  0.0  0.0   0  2.437421e+09    1.007396       16.410788
# 7   1  0.0  0.0   0  2.860856e+09    1.010938       13.981831
# 19
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 5      23.0       0.000081       16          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 5   1  0.0  0.0   0  3.332161e+09    1.007448       12.004221
# 33
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0      48.0       0.000094        7          0         0    1    1    3   1
# 1      47.0       0.000094        6          0         0    1    0    3   1
# 2      45.0       0.000093        5          0         0    0    1    3   1
# 3      44.0       0.000093        4          0         0    0    0    3   1
# 8      40.0       0.000092       18          0         0    0    0    3   1
# 9      37.0       0.000091       12          0         0    0    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  5.939285e+09    1.005595        6.734817
# 1   1  0.0  0.0   0  5.834091e+09    1.005687        6.856252
# 2   1  0.0  0.0   0  5.621679e+09    1.005782        7.115312
# 3   1  0.0  0.0   0  5.514447e+09    1.005878        7.253674
# 8   1  0.0  0.0   0  5.078526e+09    1.012439        7.876301
# 9   1  0.0  0.0   0  4.744048e+09    1.013825        8.431618
# tcp_DropTail_flow_10_0.5_Topology-incast-singlenode.tcl.tr
# 6
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 3      10.0       0.000116       18          0         0    1    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 3   1  0.0  0.0   0  1.011070e+09    1.007847       39.562055
# 33
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 1      47.0       0.000146        8          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 1   1  0.0  0.0   0  3.758193e+09    1.007396       10.643413
# 53
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 6     120.0       0.000342       20          0         0    1    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 6   1  0.0  0.0   0  4.097500e+09    1.010938        9.762049
# 133
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 2     406.0       0.000252       10          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 2   1  0.0  0.0   0  1.884559e+10    1.007448        2.122513
# 1333
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 8    2566.0       0.000853       14          0         0    0    0    3   1
# 9    1998.0       0.000683       28          0         0    0    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 8   1  0.0  0.0   0  3.513094e+10    1.012439        1.138597
# 9   1  0.0  0.0   0  3.418190e+10    1.013825        1.170210
# 3333
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0    5326.0       0.001856        7          0         0    1    1    3   1
# 4    3750.0       0.005106        4          0         0    0    0    3   1
# 5    4801.0       0.005429        6          0         0    1    0    3   1
# 7    4276.0       0.005534        5          0         0    0    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  3.352127e+10    1.005595        1.193272
# 4   1  0.0  0.0   0  8.577521e+09    1.005878        4.663352
# 5   1  0.0  0.0   0  1.032985e+10    1.005687        3.872273
# 7   1  0.0  0.0   0  9.024471e+09    1.005782        4.432393
# tcp_DropTail_flow_10_0.5_Topology-incast-singlenode-big.tcl.tr
# 133
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 2     607.0       0.005088       12          0         0    1    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 2   1  0.0  0.0   0  1.393348e+09    1.007847       28.707833
# 1333
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 1    3217.0       0.001912       14          0         0    1    0    3   1
# 3    2226.0       0.008292        8          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 1   1  0.0  0.0   0  1.964732e+10    1.010938        2.035901
# 3   1  0.0  0.0   0  3.135506e+09    1.007396       12.757111
# 3333
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 4    4185.0        0.01181       10          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 4   1  0.0  0.0   0  4.138906e+09    1.007448         9.66439
# 6667
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0   16123.0       0.005577        7          0         0    1    1    3   1
# 5    8882.0       0.012546       24          0         0    0    1    3   1
# 6   10776.0       0.018137       18          0         0    0    0    3   1
# 7   13917.0       0.026316        4          0         0    0    0    3   1
# 8   14653.0       0.026878        5          0         0    0    1    3   1
# 9   15388.0       0.026985        6          0         0    1    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  3.376828e+10    1.005595        1.184543
# 5   1  0.0  0.0   0  8.268670e+09    1.013825        4.837537
# 6   1  0.0  0.0   0  6.939462e+09    1.012439        5.764136
# 7   1  0.0  0.0   0  6.176914e+09    1.005878        6.475726
# 8   1  0.0  0.0   0  6.367610e+09    1.005782        6.281792
# 9   1  0.0  0.0   0  6.660425e+09    1.005687        6.005623

# %%
dir = "/home/ovs2/lining/Gearbox/manual/DropTail/"
df_out_tr_small = read_out_tr(dir, "small-out.tr")
df_out_tr_normal = read_out_tr(dir, "normal-out.tr")
df_out_tr_big = read_out_tr(dir, "big-out.tr")
plot_short_th(df_out_tr_small, 12, 35)
plot_short_th(df_out_tr_normal, 12, 35)
plot_short_th(df_out_tr_big, 12, 35)
# Out:
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.005884         19       35      tcp        40  C--A---
# 5        r  1.005788         19       35      tcp        40  C--A---
# 6        r  1.005693         19       35      tcp        40  C--A---
# 7        r  1.005601         19       35      tcp        40  C--A---
# 10       r  1.007853         19       35      tcp        40  C--A---
# 12       r  1.013831         19       35      tcp        40  C--A---
# 14       r  1.007402         19       35      tcp        40  C--A---
# 16       r  1.007456         19       35      tcp        40  C--A---
# 18       r  1.012445         19       35      tcp        40  C--A---
# 22       r  1.010944         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0     35.00        0    2017 00:00:01.005884
# 5        21.0     35.10        0    1920 00:00:01.005788
# 6        22.0     35.20        0    1817 00:00:01.005693
# 7        23.0     35.30        0    1718 00:00:01.005601
# 10       22.3     35.70        0    2206 00:00:01.007853
# 12       21.3     35.80        0    2357 00:00:01.013831
# 14       20.3     35.90        0    2114 00:00:01.007402
# 16       20.4     35.10        0    2139 00:00:01.007456
# 18       20.5     35.11        0    2270 00:00:01.012445
# 22       22.4     35.13        0    2225 00:00:01.010944
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.005984         19       35      tcp        40  ------N
# 5        r  1.005887         19       35      tcp        40  ------N
# 6        r  1.005793         19       35      tcp        40  ------N
# 7        r  1.005701         19       35      tcp        40  ------N
# 10       r  1.007910         19       35      tcp        40  ------N
# 12       r  1.013910         19       35      tcp      1500  ------N
# 14       r  1.007484         19       35      tcp        40  ------N
# 16       r  1.007540         19       35      tcp        40  ------N
# 18       r  1.012543         19       35      tcp        40  ------N
# 22       r  1.011027         19       35      tcp        40  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0     35.00    64241    2113 00:00:01.005984
# 5        21.0     35.10    65701    2019 00:00:01.005887
# 6        22.0     35.20    68621    1922 00:00:01.005793
# 7        23.0     35.30    70081    1822 00:00:01.005701
# 10       22.3     35.70     8761    2224 00:00:01.007910
# 12       21.3     35.80    52561    2427 00:00:01.013910
# 14       20.3     35.90    23361    2159 00:00:01.007484
# 16       20.4     35.10    33581    2205 00:00:01.007540
# 18       20.5     35.11    58401    2356 00:00:01.012543
# 22       22.4     35.13    27741    2269 00:00:01.011027
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.005942         19       35      tcp        40  C--A---
# 5        r  1.005844         19       35      tcp        40  C--A---
# 6        r  1.005697         19       35      tcp        40  C--A---
# 7        r  1.005601         19       35      tcp        40  C--A---
# 8        r  1.007446         19       35      tcp        40  C--A---
# 10       r  1.007455         19       35      tcp        40  C--A---
# 14       r  1.012445         19       35      tcp        40  C--A---
# 18       r  1.007861         19       35      tcp        40  C--A---
# 20       r  1.011004         19       35      tcp        40  C--A---
# 28       r  1.013831         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0     35.00        0    3314 00:00:01.005942
# 5        21.0     35.10        0    2662 00:00:01.005844
# 6        22.0     35.20        0    1862 00:00:01.005697
# 7        23.0     35.30        0    1718 00:00:01.005601
# 8        20.3     35.60        0   13437 00:00:01.007446
# 10       20.4     35.70        0   13642 00:00:01.007455
# 14       20.5     35.90        0   39303 00:00:01.012445
# 18       22.3     35.11        0   16238 00:00:01.007861
# 20       22.4     35.12        0   37023 00:00:01.011004
# 28       21.3     35.16        0   44442 00:00:01.013831
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.011036         19       35      tcp        40  ------N
# 5        r  1.011328         19       35      tcp        40  ------N
# 6        r  1.011142         19       35      tcp        40  ------N
# 7        r  1.007463         19       35      tcp        40  ------N
# 8        r  1.007562         19       35      tcp        40  ------N
# 10       r  1.007712         19       35      tcp        40  ------N
# 14       r  1.013305         19       35      tcp        40  ------N
# 18       r  1.007987         19       35      tcp        40  ------N
# 20       r  1.011306         19       35      tcp        40  ------N
# 28       r  1.014502         19       35      tcp      1500  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0     35.00  5475001   37312 00:00:01.011036
# 5        21.0     35.10  6242961   39302 00:00:01.011328
# 6        22.0     35.20  7009461   38108 00:00:01.011142
# 7        23.0     35.30  7775961   13682 00:00:01.007463
# 8        20.3     35.60    68621   14240 00:00:01.007562
# 10       20.4     35.70   592761   15271 00:00:01.007712
# 14       20.5     35.90  3746361   44441 00:00:01.013305
# 18       22.3     35.11    14601   17069 00:00:01.007986
# 20       22.4     35.12   175201   39207 00:00:01.011306
# 28       21.3     35.16  2915621   48234 00:00:01.014502
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.005942         19       35      tcp        40  C--A---
# 5        r  1.005844         19       35      tcp        40  C--A---
# 6        r  1.005697         19       35      tcp        40  C--A---
# 7        r  1.005601         19       35      tcp        40  C--A---
# 8        r  1.007469         19       35      tcp        40  C--A---
# 10       r  1.007519         19       35      tcp        40  C--A---
# 12       r  1.007920         19       35      tcp        40  C--A---
# 14       r  1.011009         19       35      tcp        40  C--A---
# 18       r  1.012507         19       35      tcp        40  C--A---
# 24       r  1.013878         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0     35.00        0    3314 00:00:01.005942
# 5        21.0     35.10        0    2662 00:00:01.005844
# 6        22.0     35.20        0    1862 00:00:01.005697
# 7        23.0     35.30        0    1718 00:00:01.005601
# 8        20.3     35.60        0   13514 00:00:01.007469
# 10       20.4     35.70        0   13856 00:00:01.007519
# 12       22.3     35.80        0   16544 00:00:01.007920
# 14       22.4     35.90        0   37186 00:00:01.011009
# 18       20.5     35.11        0   47220 00:00:01.012507
# 24       21.3     35.14        0   56429 00:00:01.013878
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.032239         19       35      tcp        40  ------N
# 5        r  1.032671         19       35      tcp        40  ------N
# 6        r  1.032666         19       35      tcp      1500  ------N
# 7        r  1.011185         19       35      tcp        40  ------N
# 8        r  1.015734         19       35      tcp        40  ------N
# 10       r  1.019305         19       35      tcp        40  ------N
# 12       r  1.012958         19       35      tcp        40  ------N
# 14       r  1.012872         19       35      tcp        40  ------N
# 18       r  1.030620         19       35      tcp        40  ------N
# 24       r  1.026435         19       35      tcp        40  ------N
#
#      src_addr  dst_addr   seq_num  pkt_id              ts
# fid
# 4        20.0     35.00  20318821  178981 00:00:01.032238
# 5        21.0     35.10  21393381  181957 00:00:01.032671
# 6        22.0     35.20  22465021  181865 00:00:01.032666
# 7        23.0     35.30  23539581   38576 00:00:01.011185
# 8        20.3     35.60   3249961   68890 00:00:01.015734
# 10       20.4     35.70   6110101   92707 00:00:01.019305
# 12       22.3     35.80    886221   50413 00:00:01.012958
# 14       22.4     35.90   4696821   49839 00:00:01.012872
# 18       20.5     35.11  15732961  168187 00:00:01.030620
# 24       21.3     35.14  12967721  140209 00:00:01.026435

# %%
directory = "/home/ovs2/lining/Gearbox/manual/DropTail/"
SmallDropTailDelay = DelayAnalysis(directory, 'small-out.tr')
SmallDropTailDelay.print_pkt_delay(12, 'small')
NormalDropTailDelay = DelayAnalysis(directory, 'normal-out.tr')
NormalDropTailDelay.print_pkt_delay(12, 'normal')
BigDropTailDelay = DelayAnalysis(directory, 'big-out.tr')
BigDropTailDelay.print_pkt_delay(12, 'big')

# %%
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
# print([FCT_analysis.humanbytes(i*1500) for i in flow_size])
algs=["DropTail"]


FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-small.tcl",\
                   1, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

df_out_tr_one_small = read_out_tr(dir, "onesmall-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)
# Out:
# tcp_DropTail_flow_1_0.5_Topology-incast-singlenode-small.tcl.tr
# 33
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0      48.0       0.000094        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  5.939285e+09    1.005595        6.734817
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005683         19       35      tcp      1500  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3    68621    1799 00:00:01.005683

# %%
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-supersmall.tcl",\
                   1, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

df_out_tr_one_small = read_out_tr(dir, "supersmall-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)
# Out:
# tcp_DropTail_flow_1_0.5_Topology-incast-singlenode-supersmall.tcl.tr
# 6
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0      13.0       0.000065        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  2.327150e+09    1.005595       17.188409
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005654         19       35      tcp      1500  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3    17521    1740 00:00:01.005654

# %%
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-6.tcl",\
                   1, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

df_out_tr_one_small = read_out_tr(dir, "6-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)
# Out:
# tcp_DropTail_flow_1_0.5_Topology-incast-singlenode-6.tcl.tr
# 0
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0       6.0       0.000051        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  1.362809e+09    1.005595       29.351142
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events     time  from_node  to_node pkt_type  pkt_size    flags  src_addr  \
# fid
# 7        r  1.00564         19       35      tcp      1500  ------N      23.0
#
#      dst_addr  seq_num  pkt_id              ts
# fid
# 7        35.3     7301    1729 00:00:01.005640

# %% [markdown]
# <font color='red' size="6">look into specific setting</font>
#
# Topology : Topology-incast-singlenode-unify.tcl
# flow number : 5
# load : 0.5
# ALG: all

# %%
# manual DropTail
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   5, \
                   [.5], \
                   ["DropTail"])
load = .5
FCT_analysis_small.plot_FCT_percentile_fix_load(["DropTail"], load, .95, flow_size)
df_out_tr_one_small = read_out_tr("/home/ovs2/lining/Gearbox/manual/DropTail/", "unify-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)

# manual AFQ10
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/AFQ10/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   5, \
                   [.5], \
                   ["AFQ10"])
load = .5
FCT_analysis_small.plot_FCT_percentile_fix_load(['AFQ10'], load, .95, flow_size)
df_out_tr_one_small = read_out_tr("/home/ovs2/lining/Gearbox/manual/AFQ10/", "unify-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)
# Out:
# tcp_DropTail_flow_5_0.5_Topology-incast-singlenode-unify.tcl.tr
# 33
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 1      51.0       0.000175       10          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 1   1  0.0  0.0   0  3.395964e+09    1.007396       11.778687
# 3333
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0    4729.0       0.001643        7          0         0    1    1    3   1
# 2    4361.0       0.004572        6          0         0    1    0    3   1
# 3    3625.0       0.004644        4          0         0    0    0    3   1
# 4    3993.0       0.004926        5          0         0    0    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  3.361070e+10    1.005595        1.190097
# 2   1  0.0  0.0   0  1.113983e+10    1.005687        3.590720
# 3   1  0.0  0.0   0  9.116598e+09    1.005878        4.387602
# 4   1  0.0  0.0   0  9.467755e+09    1.005782        4.224866
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.005942         19       35      tcp        40  C--A---
# 5        r  1.005844         19       35      tcp        40  C--A---
# 6        r  1.005697         19       35      tcp        40  C--A---
# 7        r  1.005601         19       35      tcp        40  C--A---
# 10       r  1.007410         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0      35.0        0    3314 00:00:01.005942
# 5        21.0      35.1        0    2662 00:00:01.005844
# 6        22.0      35.2        0    1862 00:00:01.005697
# 7        23.0      35.3        0    1718 00:00:01.005601
# 10       20.3      35.7        0   13314 00:00:01.007410
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.010547         19       35      tcp        40  ------N
# 5        r  1.010702         19       35      tcp      1500  ------N
# 6        r  1.010305         19       35      tcp        40  ------N
# 7        r  1.007251         19       35      tcp        40  ------N
# 10       r  1.007597         19       35      tcp        40  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0      35.0  5292501   34226 00:00:01.010547
# 5        21.0      35.1  5828321   35253 00:00:01.010702
# 6        22.0      35.2  6367061   32543 00:00:01.010305
# 7        23.0      35.3  6904341   12282 00:00:01.007251
# 10       20.3      35.7    74461   14550 00:00:01.007597
# tcp_AFQ10_flow_5_0.5_Topology-incast-singlenode-unify.tcl.tr
# 33
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 1      51.0       0.000095        8          0         0    0    0    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 1   1  0.0  0.0   0  6.250892e+09    1.007396        6.399087
# 3333
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0    3625.0       0.001255        4          0         0    0    0    3   1
# 2    3993.0       0.007676        5          1         0    0    1    3   1
# 3    4361.0       0.007908        6          1         0    1    0    3   1
# 4    4729.0       0.008034        7          1         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  3.372605e+10    1.005878        1.186027
# 2   1  0.0  0.0   0  6.075713e+09    1.005782        6.583590
# 3   1  0.0  0.0   0  6.441392e+09    1.005687        6.209838
# 4   1  0.0  0.0   0  6.875238e+09    1.005595        5.817981
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.005885         19       35      tcp        40  C--A---
# 5        r  1.005788         19       35      tcp        40  C--A---
# 6        r  1.005694         19       35      tcp        40  C--A---
# 7        r  1.005601         19       35      tcp        40  C--A---
# 8        r  1.007402         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0      35.0        0    2967 00:00:01.005885
# 5        21.0      35.1        0    2403 00:00:01.005788
# 6        22.0      35.2        0    1862 00:00:01.005694
# 7        23.0      35.3        0    1718 00:00:01.005601
# 8        20.3      35.6        0   10694 00:00:01.007402
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 4        r  1.007146         19       35      tcp        40  ------N
# 5        r  1.013471         19       35      tcp        40  ------N
# 6        r  1.013608         19       35      tcp        40  ------N
# 7        r  1.013623         19       35      tcp      1500  ------N
# 8        r  1.007503         19       35      tcp        40  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 4        20.0      35.0  5292501   10693 00:00:01.007146
# 5        21.0      35.1  5829781   35039 00:00:01.013471
# 6        22.0      35.2  6367061   35931 00:00:01.013608
# 7        23.0      35.3  6902881   36029 00:00:01.013623
# 8        20.3      35.6    74461   10802 00:00:01.007503

# %%
# automatic All
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/automatic/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   5, \
                   [.5], \
                   ["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"])
FCT_analysis_small.plot_FCT_percentile_fix_load(\
                ["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"],\
                .5,\
                .95,\
                flow_size)
df_out_tr_one_small = read_out_tr("/home/ovs2/lining/Gearbox/automatic/", "unify-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)
# Out:
# tcp_DropTail_flow_5_0.5_Topology-incast-singlenode-unify.tcl.tr
# tcp_AFQ10Ulim_flow_5_0.5_Topology-incast-singlenode-unify.tcl.tr
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d35ceddf90d6> in <module>
#       5                    5, \
#       6                    [.5], \
# ----> 7                    ["DropTail", "AFQ10Ulim", "AFQ10", "AFQ100", "AFQ1000", "HRCC"])
#       8 FCT_analysis_small.plot_FCT_percentile_fix_load(\
#       9                 ["DropTail", "AFQ10Ulim", "AFQ10", "AFQ100", "AFQ1000", "HRCC"],\
#
# ~/lining/Gearbox/analysis/FCT.ipynb in __init__(self, folder, toponame, flownum, loads, algs)
#
# ~/lining/Gearbox/analysis/FCT.ipynb in parse_trace(self, dir, filename)
#
# ~/lining/Gearbox/analysis/venv/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/lining/Gearbox/analysis/venv/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/lining/Gearbox/analysis/venv/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/lining/Gearbox/analysis/venv/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/lining/Gearbox/analysis/venv/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/home/ovs2/lining/Gearbox/automatic/tcp_AFQ10Ulim_flow_5_0.5_Topology-incast-singlenode-unify.tcl.tr' does not exist: b'/home/ovs2/lining/Gearbox/automatic/tcp_AFQ10Ulim_flow_5_0.5_Topology-incast-singlenode-unify.tcl.tr'
