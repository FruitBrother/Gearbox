# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from collections import OrderedDict
import matplotlib.pyplot as plt
import math
import JupyterImport
from IPython.display import display, HTML

# %%
from FCT import FCT
from shortTh import *
from delay import *
# Out:
# importing Jupyter notebook from FCT.ipynb
# importing Jupyter notebook from shortTh.ipynb
# importing Jupyter notebook from delay.ipynb

# %% [markdown]
# ### get ideal FCT of one flow

# %%
if __name__ == '__main__':
    FCT_analysis = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                       "Topology-incast-singlenode-6.tcl",\
                       1, \
                       [.5], \
                       ["DropTail"])
    
    display(FCT_analysis.raw_data[0][0])
    
    df_out_tr_6 = read_out_tr("/home/ovs2/lining/Gearbox/manual/DropTail/", "6-out.tr")
    plot_short_th(df_out_tr_6, 12, 35)
    
    Delay_6 = DelayAnalysis("/home/ovs2/lining/Gearbox/manual/DropTail/", '6-out.tr')
    Delay_6.print_pkt_delay(12, '6')
# Out:
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0       6.0       0.000051        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  1.362809e+09    1.005595       29.351142
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events     time  from_node  to_node pkt_type  pkt_size    flags  src_addr  \
# fid
# 7        r  1.00564         19       35      tcp      1500  ------N      23.0
#
#      dst_addr  seq_num  pkt_id              ts
# fid
# 7        35.3     7301    1729 00:00:01.005640

# %%
if __name__ == '__main__':
    FCT_analysis = FCT("/home/ovs2/lining/Gearbox/manual/AFQ10/", \
                       "Topology-incast-singlenode-6.tcl",\
                       1, \
                       [.5], \
                       ["AFQ10"])
    
    display(FCT_analysis.raw_data[0][0])
    
    df_out_tr_6 = read_out_tr("/home/ovs2/lining/Gearbox/manual/AFQ10/", "out.tr")
    plot_short_th(df_out_tr_6, 12, 35)
    
    Delay_6 = DelayAnalysis("/home/ovs2/lining/Gearbox/manual/AFQ10/", 'out.tr')
    Delay_6.print_pkt_delay(12, '6')
# Out:
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0       6.0       0.000051        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  1.362809e+09    1.005595       29.351142
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events     time  from_node  to_node pkt_type  pkt_size    flags  src_addr  \
# fid
# 7        r  1.00564         19       35      tcp      1500  ------N      23.0
#
#      dst_addr  seq_num  pkt_id              ts
# fid
# 7        35.3     7301    1729 00:00:01.005640

# %%
if __name__ == '__main__':
    FCT_analysis = FCT("/home/ovs2/lining/Gearbox/manual/HRCC/", \
                       "Topology-incast-singlenode-6.tcl",\
                       1, \
                       [.5], \
                       ["HRCC"])
    
    display(FCT_analysis.raw_data[0][0])
    
    df_out_tr_6 = read_out_tr("/home/ovs2/lining/Gearbox/manual/HRCC/", "out.tr")
    plot_short_th(df_out_tr_6, 12, 35)
    
    Delay_6 = DelayAnalysis("/home/ovs2/lining/Gearbox/manual/HRCC/", 'out.tr')
    Delay_6.print_pkt_delay(12, '6')
# Out:
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0       6.0       0.000051        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  1.362809e+09    1.005595       29.351142
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events     time  from_node  to_node pkt_type  pkt_size    flags  src_addr  \
# fid
# 7        r  1.00564         19       35      tcp      1500  ------N      23.0
#
#      dst_addr  seq_num  pkt_id              ts
# fid
# 7        35.3     7301    1729 00:00:01.005640

# %%
if __name__ == '__main__':
    FCT_analysis = FCT(
                       [.5], \
                       ["AFQ10PL"],\
["/home/ovs2/lining/Gearbox/automatic/flowBenchmark/tcp_AFQ10PL_Topology-incast-singlenode-fix.tcl_CDF_667.tcl.tr"])
    
    display(FCT_analysis.raw_data[0][0])
    
    df_out_tr = read_out_tr("/home/ovs2/lining/Gearbox/automatic/flowBenchmark/",\
                              "AFQ10PL_Topology-incast-singlenode-fix.tcl_CDF_667.tcl_out.tr")
    plot_short_th(df_out_tr, 12, 35)
    
    delay = DelayAnalysis("/home/ovs2/lining/Gearbox/automatic/flowBenchmark/", \
                          "AFQ10PL_Topology-incast-singlenode-fix.tcl_CDF_667.tcl_out.tr")
    delay.print_pkt_delay(12, '6')
# Out:
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0     667.0       0.000357        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  2.180700e+10    1.005595        1.834273
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005946         19       35      tcp      1500  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3   972361    3115 00:00:01.005946

# %%
if __name__ == '__main__':
    FCT_analysis = FCT(
                       [.5], \
                       ["DropTail"],\
["/home/ovs2/lining/Gearbox/automatic/flowBenchmark/tcp_DropTail_Topology-incast-singlenode-fix.tcl_CDF_667.tcl.tr"])
    
    display(FCT_analysis.raw_data[0][0])
    
    df_out_tr = read_out_tr("/home/ovs2/lining/Gearbox/automatic/flowBenchmark/",\
                              "DropTail_Topology-incast-singlenode-fix.tcl_CDF_667.tcl_out.tr")
    plot_short_th(df_out_tr, 12, 35)
    
    delay = DelayAnalysis("/home/ovs2/lining/Gearbox/automatic/flowBenchmark/", \
                          "DropTail_Topology-incast-singlenode-fix.tcl_CDF_667.tcl_out.tr")
    delay.print_pkt_delay(12, '6')
# Out:
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0     667.0       0.000283        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  2.748776e+10    1.005595        1.455193
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005872         19       35      tcp      1500  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3   972361    2848 00:00:01.005872

# %%
if __name__ == '__main__':
    FCT_analysis = FCT(
                       [.5], \
                       ["HRCCPL"],\
["/home/ovs2/lining/Gearbox/automatic/flowBenchmark/tcp_HRCCPL_Topology-incast-singlenode-fix.tcl_CDF_667.tcl.tr"])
    
    display(FCT_analysis.raw_data[0][0])
    
    df_out_tr = read_out_tr("/home/ovs2/lining/Gearbox/automatic/flowBenchmark/",\
                              "HRCCPL_Topology-incast-singlenode-fix.tcl_CDF_667.tcl_out.tr")
    plot_short_th(df_out_tr, 12, 35)
    
    delay = DelayAnalysis("/home/ovs2/lining/Gearbox/automatic/flowBenchmark/", \
                          "HRCCPL_Topology-incast-singlenode-fix.tcl_CDF_667.tcl_out.tr")
    delay.print_pkt_delay(12, '6')
# Out:
#    tmp_pkts  flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  \
# 0     667.0       0.000283        7          0         0    1    1    3   1
#
#    ?2   ?3   ?4  ?5  Average rate  start time  Normalized FCT
# 0   1  0.0  0.0   0  2.748776e+10    1.005595        1.455193
# first:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005601         19       35      tcp        40  C--A---
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3        0    1718 00:00:01.005601
# last:
#     events      time  from_node  to_node pkt_type  pkt_size    flags  \
# fid
# 7        r  1.005872         19       35      tcp      1500  ------N
#
#      src_addr  dst_addr  seq_num  pkt_id              ts
# fid
# 7        23.0      35.3   972361    2848 00:00:01.005872

# %% [markdown]
# ### plotting_mean_FCT

# %%
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
FCT_analysis = FCT("/home/ovs2/lining/Gearbox/automatic/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   500, \
                   [.1, .2, .3, .4, .5, .6, .7, .8, .9, .95], \
                   ["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"])
FCT_analysis.plotting_mean_FCT()

for load in [.8, .9, .95]:
    FCT_analysis.plot_FCT_percentile_fix_load(["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"], load, .95, flow_size)

# %%
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
# print([FCT_analysis.humanbytes(i*1500) for i in flow_size])
algs=["DropTail"]


FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-small.tcl",\
                   10, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)


FCT_analysis_normal = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode.tcl",\
                   10, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_normal.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)        


FCT_analysis_big = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-big.tcl",\
                   10, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_big.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

# %%
dir = "/home/ovs2/lining/Gearbox/manual/DropTail/"
df_out_tr_small = read_out_tr(dir, "small-out.tr")
df_out_tr_normal = read_out_tr(dir, "normal-out.tr")
df_out_tr_big = read_out_tr(dir, "big-out.tr")
plot_short_th(df_out_tr_small, 12, 35)
plot_short_th(df_out_tr_normal, 12, 35)
plot_short_th(df_out_tr_big, 12, 35)

# %%
directory = "/home/ovs2/lining/Gearbox/manual/DropTail/"
SmallDropTailDelay = DelayAnalysis(directory, 'small-out.tr')
SmallDropTailDelay.print_pkt_delay(12, 'small')
NormalDropTailDelay = DelayAnalysis(directory, 'normal-out.tr')
NormalDropTailDelay.print_pkt_delay(12, 'normal')
BigDropTailDelay = DelayAnalysis(directory, 'big-out.tr')
BigDropTailDelay.print_pkt_delay(12, 'big')

# %%
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
# print([FCT_analysis.humanbytes(i*1500) for i in flow_size])
algs=["DropTail"]


FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-small.tcl",\
                   1, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

df_out_tr_one_small = read_out_tr(dir, "onesmall-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)

# %%
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-supersmall.tcl",\
                   1, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

df_out_tr_one_small = read_out_tr(dir, "supersmall-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)

# %%
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-6.tcl",\
                   1, \
                   [.5], \
                   ["DropTail"])
for load in [.5]:
    FCT_analysis_small.plot_FCT_percentile_fix_load(algs, load, .95, flow_size)

df_out_tr_one_small = read_out_tr(dir, "6-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)

# %% [markdown]
# <font color='red' size="6">look into specific setting</font>
#
# Topology : Topology-incast-singlenode-unify.tcl
# flow number : 5
# load : 0.5
# ALG: all

# %%
# manual DropTail
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/DropTail/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   5, \
                   [.5], \
                   ["DropTail"])
load = .5
FCT_analysis_small.plot_FCT_percentile_fix_load(["DropTail"], load, .95, flow_size)
df_out_tr_one_small = read_out_tr("/home/ovs2/lining/Gearbox/manual/DropTail/", "unify-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)

# manual AFQ10
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/manual/AFQ10/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   5, \
                   [.5], \
                   ["AFQ10"])
load = .5
FCT_analysis_small.plot_FCT_percentile_fix_load(['AFQ10'], load, .95, flow_size)
df_out_tr_one_small = read_out_tr("/home/ovs2/lining/Gearbox/manual/AFQ10/", "unify-out.tr")
plot_short_th(df_out_tr_one_small, 12, 35)

# %%
# automatic All
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, float('inf')]
FCT_analysis_small = FCT("/home/ovs2/lining/Gearbox/automatic/", \
                   "Topology-incast-singlenode-unify.tcl",\
                   5, \
                   [.5], \
                   ["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"])
FCT_analysis_small.plot_FCT_percentile_fix_load(\
                ["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"],\
                .5,\
                .95,\
                flow_size)
for alg in ["DropTail", "AFQ10UlimPL", "AFQ10PL", "AFQ100PL", "AFQ1000PL", "HRCCPL"]:
    print(alg)
    filename = alg+"_flow_"+str(5)+"_"+str(0.5)+"_"+"Topology-incast-singlenode-unify.tcl"+"_out.tr"
    df_out_tr_one_small = read_out_tr("/home/ovs2/lining/Gearbox/automatic/", filename)
    plot_short_th(df_out_tr_one_small, 12, 35)

# %% [markdown]
# #### AFQ10UlimPL 小流争用？
# 只争用一个流

# %% [markdown]
# ## Normalize the FCT with standard
