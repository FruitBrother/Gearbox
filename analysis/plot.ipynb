# %%
import JupyterImport
from delay import *
from QueueLen import *
from FCT import *
from shortTh import *
# Out:
# importing Jupyter notebook from delay.ipynb
# importing Jupyter notebook from QueueLen.ipynb
# importing Jupyter notebook from FCT.ipynb
# importing Jupyter notebook from shortTh.ipynb

# %%
flow_size=[0, 6, 13, 19, 33, 53, 133, 667, 1333, 3333, 6667, 20000, float('inf')]
original_lists=[flow_size[1:-1],[40 * 1e9 for i in range(len(flow_size) - 2)]]
plt.plot(original_lists[0], original_lists[1])

# %%
def parse_trace(file, normalizor):
    col = ["tmp_pkts", "flow duration", "fin_fid", "rtt times", \
               "group_id", "Tw_", "Tp_", "Np_", "?1", "?2", "?3", "?4", "?5", "Average rate", "start time"]
    df = pd.read_csv(file, sep = ' ', header = None)
    df.columns = col
    df["Normalized FCT"] = 40 * 1e9  / df["Average rate"]
    return df

# %%
tracefile = "/home/ovs2/eval/tcp_random_pair_32host/diff_host_4pods/4host_FID/tcp-incast-HRCC/tcp_flow_1000_0.9_Topology-4hosts-4pods-random.tcl.tr"
df = parse_trace(tracefile, original_lists)

# %%
df_one = df.loc[df['tmp_pkts']<20]

# %%
pkt_size_break=df.groupby("tmp_pkts").first()

# %%
pkt_size_break
# Out:
#           flow duration  fin_fid  rtt times  group_id  Tw_  Tp_  Np_  ?1  ?2  \
# tmp_pkts
# 6.0            0.000050      920          0         0    0    3    3   0   0
# 7.0            0.000051     1194          0         2    1    1    0   0   2
# 8.0            0.000063     1202          0         2    1    2    0   0   2
# 9.0            0.000099     1802          0         0    1    1    2   0   3
# 10.0           0.000063     1210          0         2    1    3    0   0   2
# 11.0           0.000081     1306          0         2    0    3    3   0   2
# 12.0           0.000065     1346          0         3    0    0    0   0   2
# 13.0           0.000067     1354          0         3    0    1    0   0   2
# 14.0           0.000065     1362          0         3    0    2    0   0   2
# 15.0           0.000064     1378          0         3    1    0    0   0   2
# 16.0           0.000076     1386          0         3    1    1    0   0   2
# 17.0           0.000116     1894          0         3    1    1    2   1   1
# 18.0           0.000076      903          0         0    0    0    3   1   3
# 19.0           0.000077      911          0         0    0    1    3   1   3
# 20.0           0.000077      919          0         0    0    2    3   1   3
# 21.0           0.000077      967          0         1    0    0    0   1   3
# 22.0           0.000101     1275          0         2    1    3    1   0   3
# 23.0           0.000077      975          0         1    0    1    0   1   3
# 24.0           0.000077      983          0         1    0    2    0   1   3
# 25.0           0.000087     1419          0         3    0    1    1   0   3
# 26.0           0.000078      991          0         1    0    3    0   1   3
# 27.0           0.000078      999          0         1    1    0    0   1   3
# 28.0           0.000079     1435          0         3    0    3    1   0   3
# 29.0           0.000080     1007          0         1    1    1    0   1   3
# 30.0           0.000082     1015          0         1    1    2    0   1   3
# 31.0           0.000092      840          0         0    0    1    2   0   0
# 32.0           0.000089     1023          0         1    1    3    0   1   3
# 33.0           0.000098     1119          0         1    0    3    3   1   3
# 34.0           0.000100      856          0         0    0    3    2   0   0
# 35.0           0.000101     1127          0         1    1    0    3   1   3
# ...                 ...      ...        ...       ...  ...  ...  ...  ..  ..
# 8765.0         0.010576      996          0         1    1    0    0   1   0
# 8863.0         0.007094      823          0         0    1    2    1   1   3
# 8963.0         0.008259      898          0         0    0    0    3   0   2
# 8971.0         0.005195     2814          0         1    1    3    3   0   1
# 11481.0        0.012473     2136          0         3    1    1    1   0   1
# 11622.0        0.014258     1509          0         3    1    0    2   1   1
# 11633.0        0.014261     1686          0         3    0    3    1   0   1
# 12239.0        0.013660     1432          0         3    0    3    1   0   0
# 12434.0        0.012783     1150          0         1    1    3    3   1   2
# 12777.0        0.011361     1640          0         2    0    3    3   0   2
# 12954.0        0.010943     1190          0         2    1    0    0   1   2
# 13151.0        0.013636     1092          0         1    0    0    3   1   0
# 13668.0        0.009823     1004          0         1    1    1    0   1   0
# 13766.0        0.006100      831          0         0    1    3    1   1   3
# 13866.0        0.010154      906          0         0    0    1    3   0   2
# 14042.0        0.011590     2466          0         1    0    0    3   1   2
# 14108.0        0.007302     2118          0         3    0    1    2   0   2
# 14236.0        0.013437     1650          0         0    1    0    3   1   3
# 14483.0        0.007450      773          0         0    0    0    1   1   1
# 15879.0        0.008253     2364          0         2    0    3    0   0   2
# 15882.0        0.015222     2162          0         0    0    3    1   0   3
# 16525.0        0.015511     1517          0         3    1    1    2   1   1
# 16896.0        0.009487     3038          0         2    0    0    1   1   3
# 17142.0        0.014631     1440          0         3    1    0    1   0   0
# 17337.0        0.014350     1286          0         2    0    0    3   1   2
# 17857.0        0.012533     1198          0         2    1    1    0   1   2
# 18054.0        0.016230     1100          0         1    0    1    3   1   0
# 18571.0        0.013303     1012          0         1    1    2    0   1   0
# 18769.0        0.011868      914          0         0    0    2    3   0   2
# 19386.0        0.011753      781          0         0    0    1    1   1   1
#
#            ?3   ?4  ?5  Average rate  start time  Normalized FCT
# tmp_pkts
# 6.0       0.0  0.0   0  1.387745e+09    1.000009       28.823744
# 7.0       0.0  0.0   0  1.615095e+09    1.000236       24.766341
# 8.0       0.0  0.0   0  1.483212e+09    1.000208       26.968493
# 9.0       0.0  0.0   0  1.059881e+09    1.001106       37.740080
# 10.0      0.0  0.0   0  1.843717e+09    1.000180       21.695305
# 11.0      0.0  0.0   0  1.580952e+09    1.000388       25.301211
# 12.0      0.0  0.0   0  2.151700e+09    1.000152       18.589951
# 13.0      0.0  0.0   0  2.283130e+09    1.000125       17.519808
# 14.0      0.0  0.0   0  2.526802e+09    1.000097       15.830289
# 15.0      0.0  0.0   0  2.743880e+09    1.000043       14.577900
# 16.0      0.0  0.0   0  2.467467e+09    1.000016       16.210959
# 15882.0   0.0  0.0   0  1.218642e+10    1.002518        3.282342
# 16525.0   0.0  0.0   0  1.244386e+10    1.000505        3.214437
# 16896.0   0.0  0.0   0  2.080250e+10    1.005779        1.922846
# 17142.0   0.0  0.0   0  1.368455e+10    1.003393        2.923004
# 17337.0   0.0  0.0   0  1.411082e+10    1.002667        2.834705
# 17857.0   0.0  0.0   0  1.664111e+10    1.002290        2.403686
# 18054.0   0.0  0.0   0  1.299234e+10    1.001707        3.078737
# 18571.0   0.0  0.0   0  1.630570e+10    1.001397        2.453129
# 18769.0   0.0  0.0   0  1.847222e+10    1.000910        2.165414
# 19386.0   0.0  0.0   0  1.926519e+10    1.004170        2.076283
#
# [491 rows x 15 columns]

# %% [markdown]
# 15879.0	0.008253	**2364**	0	2	0	3	0	0	2	0.0	0.0	0	2.247286e+10	1.003302	1.779925

# %%
directory = "/home/ovs2/eval/tcp_random_pair_32host/diff_host_4pods/4host_FID/out_tr/4p4h1000f/"
filename = "4p4h1000f_HRCC_out.tr"

# %%
delay = DelayAnalysis(directory, filename, fid = 2364)
delay.print_pkt_delay(12, title = filename)

# %%
#df_out = read_out_tr(directory, filename)
plot_flow_path_queue_length(delay.raw_data, 2364)
# Out:
# from [39 16  5 11  1 12]
# to [16  5 11  1 12 22]

# %%
filename = "4p4h1000f_AFQ10_out.tr"
delay = DelayAnalysis(directory, filename, fid = 2364)
delay.print_pkt_delay(12, title = filename)
plot_flow_path_queue_length(delay.raw_data, 2364)
# Out:
# from [38 16  4  8  2 14]
# to [16  4  8  2 14 31]

# %%
tracefile = "/home/ovs2/eval/tcp_random_pair_32host/diff_host_4pods/4host_FID/tcp-incast-AFQ100/tcp_flow_1000_0.9_Topology-4hosts-4pods-random.tcl.tr"
df = parse_trace(tracefile, original_lists)

# %%
df.loc[df['fin_fid'].isin([2364])]
# Out:
# Empty DataFrame
# Columns: [tmp_pkts, flow duration, fin_fid, rtt times, group_id, Tw_, Tp_, Np_, ?1, ?2, ?3, ?4, ?5, Average rate, start time, Normalized FCT]
# Index: []

# %%
filename = "4p4h1000f_AFQ100_out.tr"
delay = DelayAnalysis(directory, filename, fid = 2364)
delay.print_pkt_delay(12, title = filename)
plot_flow_path_queue_length(delay.raw_data, 2364)
# Out:
# from []
# to []

# %%
filename = "4p4h1000f_AFQ1000_out.tr"
delay = DelayAnalysis(directory, filename, fid = 2364)
delay.print_pkt_delay(12, title = filename)
plot_flow_path_queue_length(delay.raw_data, 2364)
# Out:
# from []
# to []

# %%
filename = "4p4h1000f_DropTail_out.tr"
delay = DelayAnalysis(directory, filename, fid = 2364)
delay.print_pkt_delay(12, title = filename)
plot_flow_path_queue_length(delay.raw_data, 2364)
# Out:
# from [38 16  4  8  2 14]
# to [16  4  8  2 14 31]
